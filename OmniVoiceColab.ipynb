# %%
#@title Install OmniVoice
# %cd /content/
# !rm -rf ./Omini
# !git clone https://github.com/Sanjux143/Omini.git
# %cd ./Omini
# !git clone https://github.com/Sanjux143/OmniVoice.git
# !pip install -r colab.txt
# !pip install -r requirements.txt
from IPython.display import clear_output
clear_output()

# %%
#@title Run Gradio APP
# %cd /content/Omini
# !python app.py
# Out:
# /content/Omini
# Loading model from k2-fsa/OmniVoice to cuda ...
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 2026-08-13 01:11:08,861 huggingface_hub.utils._http WARNING: Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json: 100% 2.24k/2.24k [00:00<00:00, 6.49MB/s]
#
# model.safetensors: downloading bytes:   8% 205M/2.45G [00:01<00:07, 289MB/s, 15.7MB/s  ]
# model.safetensors: downloading bytes:  10% 254M/2.45G [00:01<00:08, 267MB/s, 22.4MB/s  ]
# model.safetensors: downloading bytes:  12% 289M/2.45G [00:01<00:09, 223MB/s, 25.4MB/s  ]
# model.safetensors: downloading bytes:  19% 459M/2.45G [00:02<00:06, 313MB/s, 38.3MB/s  ]
# model.safetensors: downloading bytes:  30% 743M/2.45G [00:03<00:05, 306MB/s, 61.9MB/s  ]
# model.safetensors: downloading bytes:  32% 776M/2.45G [00:03<00:06, 254MB/s, 64.8MB/s  ]
# model.safetensors: downloading bytes:  41% 999M/2.45G [00:04<00:05, 275MB/s, 79.6MB/s  ]
# model.safetensors: downloading bytes:  44% 1.08G/2.45G [00:04<00:05, 232MB/s, 84.0MB/s  ]
# model.safetensors: downloading bytes:  48% 1.17G/2.45G [00:04<00:04, 267MB/s, 88.7MB/s  ]
# model.safetensors: downloading bytes:  55% 1.34G/2.45G [00:05<00:04, 275MB/s, 99.4MB/s  ]
# model.safetensors: downloading bytes:  56% 1.37G/2.45G [00:05<00:04, 239MB/s,  100MB/s  ]
# model.safetensors: downloading bytes:  57% 1.41G/2.45G [00:05<00:04, 217MB/s,  102MB/s  ]
# model.safetensors: downloading bytes:  59% 1.45G/2.45G [00:06<00:04, 214MB/s,  103MB/s  ]
# model.safetensors: downloading bytes:  86% 2.12G/2.45G [00:08<00:01, 249MB/s,  137MB/s  ]
# model.safetensors: downloading bytes:  94% 2.29G/2.45G [00:08<00:00, 276MB/s,  145MB/s  ]
# model.safetensors: reconstructing file:  74% 1.81G/2.45G [00:09<00:03, 205MB/s,  106MB/s  ]
# model.safetensors: downloading bytes: 100% 2.32G/2.32G [00:12<00:00, 181MB/s,  145MB/s  ]
# model.safetensors: reconstructing file: 100% 2.45G/2.45G [00:12<00:00, 191MB/s,  138MB/s  ]
# Loading weights: 100% 313/313 [00:04<00:00, 63.60it/s]
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 13 files:   0% 0/13 [00:00<?, ?it/s]
# Reconstructing (incomplete total...):   0% 0.00/806M [00:00<?, ?B/s]
# Reconstructing (incomplete total...):   0% 0.00/806M [00:00<?, ?B/s]
# Downloading bytes:   0% 9.17k/806M [00:00<3:33:30, 62.9kB/s]
# Reconstructing (incomplete total...):   0% 9.17k/806M [00:00<3:32:46, 63.1kB/s]
# Reconstructing (incomplete total...):   0% 14.3k/806M [00:00<3:32:46, 63.1kB/s]
# Reconstructing (incomplete total...):   0% 23.8k/817M [00:00<3:35:47, 63.1kB/s]
# Reconstructing (incomplete total...):   0% 23.8k/817M [00:00<3:35:47, 63.1kB/s]
# Reconstructing (incomplete total...):   0% 23.8k/817M [00:00<3:35:47, 63.1kB/s]
# Reconstructing (incomplete total...):   0% 26.5k/817M [00:00<3:35:47, 63.1kB/s]
#
# Fetching 13 files:   8% 1/13 [00:00<00:01,  6.19it/s]
# Reconstructing (incomplete total...):   0% 28.1k/817M [00:00<3:35:47, 63.1kB/s]
# Reconstructing (incomplete total...):   0% 29.6k/817M [00:00<3:35:47, 63.1kB/s]
# Reconstructing (incomplete total...):   0% 29.6k/817M [00:00<3:35:47, 63.1kB/s]
# Downloading bytes:   0% 33.8k/817M [00:00<1:37:57, 139kB/s]
# Downloading bytes:   5% 44.6M/817M [00:00<00:08, 87.4MB/s,  187kB/s  ]
# Downloading bytes:  10% 77.9M/817M [00:00<00:05, 145MB/s,  333kB/s  ]
# Downloading bytes:  27% 222M/817M [00:01<00:02, 290MB/s, 17.8MB/s  ]
# Reconstructing (incomplete total...):  10% 78.6M/817M [00:01<00:09, 81.5MB/s, 1.56MB/s  ]
# Downloading bytes:  32% 259M/817M [00:01<00:02, 239MB/s, 23.1MB/s  ]
# Downloading bytes:  79% 648M/817M [00:03<00:00, 206MB/s, 50.9MB/s  ]
# Reconstructing (incomplete total...):  47% 385M/817M [00:06<00:07, 56.0MB/s, 19.0MB/s  ]
# Reconstructing (incomplete total...):  54% 438M/817M [00:06<00:05, 69.3MB/s, 27.6MB/s  ]
# Reconstructing (incomplete total...):  58% 470M/817M [00:06<00:04, 79.1MB/s, 32.0MB/s  ]
# Reconstructing (incomplete total...):  64% 525M/817M [00:06<00:02, 98.2MB/s, 34.5MB/s  ]
# Reconstructing (incomplete total...):  71% 581M/817M [00:06<00:01, 121MB/s, 38.6MB/s  ]
# Reconstructing (incomplete total...):  77% 629M/817M [00:06<00:01, 149MB/s, 42.8MB/s  ]
# Reconstructing (incomplete total...):  84% 685M/817M [00:07<00:00, 174MB/s, 46.5MB/s  ]
# Reconstructing (incomplete total...):  90% 733M/817M [00:07<00:00, 209MB/s, 50.5MB/s  ]
# Reconstructing (incomplete total...): 100% 817M/817M [00:07<00:00, 243MB/s, 54.1MB/s  ]
#
# Fetching 13 files: 100% 13/13 [00:07<00:00,  1.73it/s]
# Download complete: 100% 663M/663M [00:07<00:00, 206MB/s, 52.2MB/s  ]
# Download complete: 100% 663M/663M [00:09<00:00, 71.2MB/s, 52.2MB/s  ]
# Reconstruction complete: 100% 817M/817M [00:09<00:00, 87.8MB/s, 60.1MB/s  ]
# Loading weights: 100% 527/527 [00:00<00:00, 1446.47it/s]
# Model loaded successfully!
# /content/Omini/app.py:325: DeprecationWarning: The 'theme' parameter in the Blocks constructor will be removed in Gradio 6.0. You will need to pass 'theme' to Blocks.launch() instead.
#   with gr.Blocks(theme=theme, css=css, title="OmniVoice Demo") as demo:
# /content/Omini/app.py:325: DeprecationWarning: The 'css' parameter in the Blocks constructor will be removed in Gradio 6.0. You will need to pass 'css' to Blocks.launch() instead.
#   with gr.Blocks(theme=theme, css=css, title="OmniVoice Demo") as demo:
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://02d9a650c05169bcab.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
